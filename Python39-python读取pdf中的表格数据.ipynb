# %% [markdown]
# ** 参考**：
# - [官方API](http://euske.github.io/pdfminer/programming.html)
# - [百度经验-Python pdfminer使用教程pdf文件处理](https://jingyan.baidu.com/article/d169e186602a62436711d841.html)
# - [Extracting Text & Images from PDF Files](http://denis.papathanasiou.org/posts/2010.08.04.post.html)

# %% [markdown]
# - PDFParser：从一个文件中获取数据
# - PDFDocument：保存获取的数据，和PDFParser是相互关联的
# - PDFPageInterPReter处理页面内容
# - PDFDevice将其翻译成你需要的格式
# - PDFResourceManager用于存储共享资源，如字体或图像。

# %%
from pdfminer.pdfparser import PDFParser,PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import PDFPageAggregator
from pdfminer.layout import LTTextBoxHorizontal,LAParams
from pdfminer.pdfinterp import PDFTextExtractionNotAllowed

# %%
from urllib.request import urlopen
from pdfminer.pdfinterp import PDFResourceManager,process_pdf
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO
from io import open
def readPDF(pdffile):
    rsrcmgr=PDFResourceManager()
    retstr=StringIO()
    laparams=LAParams()
    device=TextConverter(rsrcmgr,retstr,laparams=laparams)
    process_pdf(rsrcmgr,device,pdffile)
    device.close()
    content=retstr.getvalue()
    retstr.close()
    return content
# pdffile=urlopen('http://pythonscraping.com/pages/warandpeace/chapter1.pdf')
pdffile=open('data/caibao.pdf','rb')
outputString=readPDF(pdffile)
print(outputString)
pdffile.close()
# Out:
# WARNING:pdfminer.layout:Too many boxes (144) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (103) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (113) to group, skipping.
# WARNING:pdfminer.layout:Too many boxes (101) to group, skipping.
# 2017 年第一季度报告
#
# 公司代码：600028                                               公司简称：中国石化
#
# 中国石油化工股份有限公司
# 2017 年第一季度报告
#
# 1 / 31
#
#
#
#
#
#
#
# 2017 年第一季度报告
#
# 目录
#
# 一、
# 二、
# 三、
# 四、
#
# 重要提示 .............................................................. 3
# 公司基本情况 .......................................................... 4
# 重要事项 .............................................................. 9
# 附录 ................................................................. 11
#
# 2 / 31
#
#
# 2017 年第一季度报告
#
# 一、 重要提示
#
# 1.1 中国石油化工股份有限公司（“中国石化”或“本公司”）董事会、监事会及其董事、监事、
#
# 高级管理人员保证本季度报告所载资料不存在任何虚假记载、误导性陈述或者重大遗漏，并
#
# 对其内容的真实性、准确性和完整性负个别及连带责任。
#
# 1.2  本季度报告已经中国石化第六届董事会第十三次会议审议通过。公司全体董事出席董事会审
#
# 议季度报告。
#
# ...

# %%
#获取PDF目录，如果没有目录报错
from pdfminer.pdfparser import PDFParser, PDFDocument
file=open('data/caibao.pdf', 'rb')
parser=PDFParser(file)
document=PDFDocument()
parser.set_document(document)
document.set_parser(parser)
document.initialize('')
outlines=document.get_outlines()
for (level,title,dest,a,se) in outlines:
    print (level, title,dest,a,se)
# Out:
# ---------------------------------------------------------------------------
# PDFNoOutlines                             Traceback (most recent call last)
# <ipython-input-10-9809aff41bb8> in <module>()
#       7 document.set_parser(parser)
#       8 document.initialize('')
# ----> 9 outlines=document.get_outlines()
#      10 for (level,title,dest,a,se) in outlines:
#      11     print (level, title,dest,a,se)
#
# G:\ProgramData\Anaconda3\lib\site-packages\pdfminer\pdfparser.py in get_outlines(self)
#     571     def get_outlines(self):
#     572         if 'Outlines' not in self.catalog:
# --> 573             raise PDFNoOutlines
#     574         def search(entry, level):
#     575             entry = dict_value(entry)
#
# PDFNoOutlines:
