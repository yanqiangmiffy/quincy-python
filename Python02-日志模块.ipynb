# %%
# import logging
# #默认输出且只显示了大于等于WARNING级别的日志
# logging.debug('debug message')
# logging.info('info message')
# logging.warning('warning message')
# logging.error('error message')
# logging.critical('critical message')
# Out:
# WARNING:root:warning message
# ERROR:root:error message
# CRITICAL:root:critical message

# %%
import logging
logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s %(filename)s[line:%(lineno)d] %(levelname)s %(message)s',
                    datefmt='%a,%d %b %Y %H:%M:%S',
                    filename='log.log',
                    filemode='w')
logging.debug('debug message')
logging.info('info message')
logging.warning('warning message')
logging.error('error message')
logging.critical('critical message')
# Out:
# WARNING:root:warning message
# ERROR:root:error message
# CRITICAL:root:critical message

# %%
import logging

#创建logger
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)#设置logger的级别

logger1 = logging.getLogger('myLogger')
logger1.setLevel(logging.DEBUG)
logger2 = logging.getLogger('myLogger')
logger2.setLevel(logging.INFO)
logger3 = logging.getLogger('myLogger')
logger3.setLevel(logging.CRITICAL)
logger4 = logging.getLogger('myLogger')
logger4.setLevel(logging.WARNING)
logger5 = logging.getLogger('myLogger.child')
logger5.setLevel(logging.DEBUG)

#创建一个handler,用于写日志文件
fh = logging.FileHandler('process2.log')
#再创建一个handler用于输出到控制台
sh = logging.StreamHandler()

#定义handler输出格式
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fh.setFormatter(formatter)
sh.setFormatter(formatter)

#给logger添加handler
logger.addHandler(fh)
logger.addHandler(sh)

logger1.addHandler(fh)
logger1.addHandler(sh)

logger2.addHandler(fh)
logger2.addHandler(sh)

logger2.addHandler(fh)
logger2.addHandler(sh)

logger3.addHandler(fh)
logger3.addHandler(sh)

logger4.addHandler(fh)
logger4.addHandler(sh)

logger5.addHandler(fh)
logger5.addHandler(sh)

# 记录一条日志
logger.debug('logger debug message')
logger.info('logger info message')
logger.warning('logger warning message')
logger.error('logger error message')
logger.critical('logger critical message')

logger1.debug('logger1 debug message')
logger1.info('logger1 info message')
logger1.warning('logger1 warning message')
logger1.error('logger1 error message')
logger1.critical('logger1 critical message')

logger2.debug('logger2 debug message')
logger2.info('logger2 info message')
logger2.warning('logger2 warning message')
logger2.error('logger2 error message')
logger2.critical('logger2 critical message')

logger3.debug('logger3 debug message')
logger3.info('logger3 info message')
logger3.warning('logger3 warning message')
logger3.error('logger3 error message')
logger3.critical('logger3 critical message')

logger4.debug('logger4 debug message')
logger4.info('logger4 info message')
logger4.warning('logger4 warning message')
logger4.error('logger4 error message')
logger4.critical('logger4 critical message')

logger5.debug('logger5 debug message')
logger5.info('logger5 info message')
logger5.warning('logger5 warning message')
logger5.error('logger5 error message')
logger5.critical('logger5 critical message')
# Out:
# DEBUG:root:logger debug message
# 2017-06-06 15:15:50,131 - root - DEBUG - logger debug message
# 2017-06-06 15:15:50,131 - root - DEBUG - logger debug message
# INFO:root:logger info message
# 2017-06-06 15:15:50,135 - root - INFO - logger info message
# 2017-06-06 15:15:50,135 - root - INFO - logger info message
# WARNING:root:logger warning message
# 2017-06-06 15:15:50,142 - root - WARNING - logger warning message
# 2017-06-06 15:15:50,142 - root - WARNING - logger warning message
# ERROR:root:logger error message
# 2017-06-06 15:15:50,145 - root - ERROR - logger error message
# 2017-06-06 15:15:50,145 - root - ERROR - logger error message
# CRITICAL:root:logger critical message
# 2017-06-06 15:15:50,149 - root - CRITICAL - logger critical message
# 2017-06-06 15:15:50,149 - root - CRITICAL - logger critical message
# 2017-06-06 15:15:50,154 - myLogger - WARNING - logger1 warning message
# 2017-06-06 15:15:50,154 - myLogger - WARNING - logger1 warning message
# WARNING:myLogger:logger1 warning message
# 2017-06-06 15:15:50,154 - myLogger - WARNING - logger1 warning message
# 2017-06-06 15:15:50,154 - myLogger - WARNING - logger1 warning message
# 2017-06-06 15:15:50,162 - myLogger - ERROR - logger1 error message
# 2017-06-06 15:15:50,162 - myLogger - ERROR - logger1 error message
# ERROR:myLogger:logger1 error message
# 2017-06-06 15:15:50,162 - myLogger - ERROR - logger1 error message
# 2017-06-06 15:15:50,162 - myLogger - ERROR - logger1 error message
# 2017-06-06 15:15:50,167 - myLogger - CRITICAL - logger1 critical message
# 2017-06-06 15:15:50,167 - myLogger - CRITICAL - logger1 critical message
# CRITICAL:myLogger:logger1 critical message
# 2017-06-06 15:15:50,167 - myLogger - CRITICAL - logger1 critical message
# 2017-06-06 15:15:50,167 - myLogger - CRITICAL - logger1 critical message
# 2017-06-06 15:15:50,176 - myLogger - WARNING - logger2 warning message
# 2017-06-06 15:15:50,176 - myLogger - WARNING - logger2 warning message
# WARNING:myLogger:logger2 warning message
# 2017-06-06 15:15:50,176 - myLogger - WARNING - logger2 warning message
# 2017-06-06 15:15:50,176 - myLogger - WARNING - logger2 warning message
# 2017-06-06 15:15:50,182 - myLogger - ERROR - logger2 error message
# 2017-06-06 15:15:50,182 - myLogger - ERROR - logger2 error message
# ERROR:myLogger:logger2 error message
# 2017-06-06 15:15:50,182 - myLogger - ERROR - logger2 error message
# 2017-06-06 15:15:50,182 - myLogger - ERROR - logger2 error message
# 2017-06-06 15:15:50,188 - myLogger - CRITICAL - logger2 critical message
# 2017-06-06 15:15:50,188 - myLogger - CRITICAL - logger2 critical message
# CRITICAL:myLogger:logger2 critical message
# 2017-06-06 15:15:50,188 - myLogger - CRITICAL - logger2 critical message
# 2017-06-06 15:15:50,188 - myLogger - CRITICAL - logger2 critical message
# 2017-06-06 15:15:50,193 - myLogger - WARNING - logger3 warning message
# 2017-06-06 15:15:50,193 - myLogger - WARNING - logger3 warning message
# WARNING:myLogger:logger3 warning message
# 2017-06-06 15:15:50,193 - myLogger - WARNING - logger3 warning message
# 2017-06-06 15:15:50,193 - myLogger - WARNING - logger3 warning message
# 2017-06-06 15:15:50,198 - myLogger - ERROR - logger3 error message
# 2017-06-06 15:15:50,198 - myLogger - ERROR - logger3 error message
# ERROR:myLogger:logger3 error message
# 2017-06-06 15:15:50,198 - myLogger - ERROR - logger3 error message
# 2017-06-06 15:15:50,198 - myLogger - ERROR - logger3 error message
# 2017-06-06 15:15:50,204 - myLogger - CRITICAL - logger3 critical message
# 2017-06-06 15:15:50,204 - myLogger - CRITICAL - logger3 critical message
# CRITICAL:myLogger:logger3 critical message
# 2017-06-06 15:15:50,204 - myLogger - CRITICAL - logger3 critical message
# 2017-06-06 15:15:50,204 - myLogger - CRITICAL - logger3 critical message
# 2017-06-06 15:15:50,209 - myLogger - WARNING - logger4 warning message
# 2017-06-06 15:15:50,209 - myLogger - WARNING - logger4 warning message
# WARNING:myLogger:logger4 warning message
# 2017-06-06 15:15:50,209 - myLogger - WARNING - logger4 warning message
# 2017-06-06 15:15:50,209 - myLogger - WARNING - logger4 warning message
# 2017-06-06 15:15:50,214 - myLogger - ERROR - logger4 error message
# 2017-06-06 15:15:50,214 - myLogger - ERROR - logger4 error message
# ERROR:myLogger:logger4 error message
# 2017-06-06 15:15:50,214 - myLogger - ERROR - logger4 error message
# 2017-06-06 15:15:50,214 - myLogger - ERROR - logger4 error message
# 2017-06-06 15:15:50,221 - myLogger - CRITICAL - logger4 critical message
# 2017-06-06 15:15:50,221 - myLogger - CRITICAL - logger4 critical message
# CRITICAL:myLogger:logger4 critical message
# 2017-06-06 15:15:50,221 - myLogger - CRITICAL - logger4 critical message
# 2017-06-06 15:15:50,221 - myLogger - CRITICAL - logger4 critical message
# 2017-06-06 15:15:50,231 - myLogger.child - DEBUG - logger5 debug message
# 2017-06-06 15:15:50,231 - myLogger.child - DEBUG - logger5 debug message
# 2017-06-06 15:15:50,231 - myLogger.child - DEBUG - logger5 debug message
# 2017-06-06 15:15:50,231 - myLogger.child - DEBUG - logger5 debug message
# DEBUG:myLogger.child:logger5 debug message
# 2017-06-06 15:15:50,231 - myLogger.child - DEBUG - logger5 debug message
# 2017-06-06 15:15:50,231 - myLogger.child - DEBUG - logger5 debug message
# 2017-06-06 15:15:50,239 - myLogger.child - INFO - logger5 info message
# 2017-06-06 15:15:50,239 - myLogger.child - INFO - logger5 info message
# 2017-06-06 15:15:50,239 - myLogger.child - INFO - logger5 info message
# 2017-06-06 15:15:50,239 - myLogger.child - INFO - logger5 info message
# INFO:myLogger.child:logger5 info message
# 2017-06-06 15:15:50,239 - myLogger.child - INFO - logger5 info message
# 2017-06-06 15:15:50,239 - myLogger.child - INFO - logger5 info message
# 2017-06-06 15:15:50,246 - myLogger.child - WARNING - logger5 warning message
# 2017-06-06 15:15:50,246 - myLogger.child - WARNING - logger5 warning message
# 2017-06-06 15:15:50,246 - myLogger.child - WARNING - logger5 warning message
# 2017-06-06 15:15:50,246 - myLogger.child - WARNING - logger5 warning message
# WARNING:myLogger.child:logger5 warning message
# 2017-06-06 15:15:50,246 - myLogger.child - WARNING - logger5 warning message
# 2017-06-06 15:15:50,246 - myLogger.child - WARNING - logger5 warning message
# 2017-06-06 15:15:50,251 - myLogger.child - ERROR - logger5 error message
# 2017-06-06 15:15:50,251 - myLogger.child - ERROR - logger5 error message
# 2017-06-06 15:15:50,251 - myLogger.child - ERROR - logger5 error message
# 2017-06-06 15:15:50,251 - myLogger.child - ERROR - logger5 error message
# ERROR:myLogger.child:logger5 error message
# 2017-06-06 15:15:50,251 - myLogger.child - ERROR - logger5 error message
# 2017-06-06 15:15:50,251 - myLogger.child - ERROR - logger5 error message
# 2017-06-06 15:15:50,257 - myLogger.child - CRITICAL - logger5 critical message
# 2017-06-06 15:15:50,257 - myLogger.child - CRITICAL - logger5 critical message
# 2017-06-06 15:15:50,257 - myLogger.child - CRITICAL - logger5 critical message
# 2017-06-06 15:15:50,257 - myLogger.child - CRITICAL - logger5 critical message
# CRITICAL:myLogger.child:logger5 critical message
# 2017-06-06 15:15:50,257 - myLogger.child - CRITICAL - logger5 critical message
# 2017-06-06 15:15:50,257 - myLogger.child - CRITICAL - logger5 critical message
